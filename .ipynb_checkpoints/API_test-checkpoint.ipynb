# %%
import joblib
import os
from API.utils import *
import pandas as pd
import numpy as np
os.listdir('./model')
# Out:
# ['ANN(58_to_sp162).pkl',
#  'SVR(5_to_23).pkl',
#  'transformer(23_to_54).pkl',
#  'transformer(SP162_to_Y162).pkl']

# %% [markdown]
# # load pretrained model

# %%
A = joblib.load('./model/SVR(5_to_23).pkl')
B = joblib.load('./model/transformer(23_to_54).pkl')
C = joblib.load('./model/ANN(58_to_sp162).pkl')
D = joblib.load('./model/transformer(SP162_to_Y162).pkl')

# %% [markdown]
# # input data

# %%
df = pd.read_csv('./data/phase_1/test_170.csv',index_col=0).head(1)
y_test = df.iloc[:,4:]
df['P'] = 100 - df['N+A']
X_test = df[['T10','T50','T90','N+A','P']]
X_test
# Out:
#     T10    T50    T90     N+A       P
# 0  98.6  119.2  146.1  40.133  59.867

# %% [markdown]
# # step1

# %%
y_pred23 = A.predict(X_test)
y_pred23 = pd.DataFrame(y_pred23,columns=y_test.columns)
print(y_pred23.sum(axis=1))
y_pred23.head()
# Out:
# 0    100.0
# dtype: float64
#        C5NP      C5IP       C5N     C6NP      C6IP       C6N       C6A  \
# 0  1.203686  0.819795  0.162816  3.60144  2.287253  3.558247  0.671907
#
#        C7NP      C7IP       C7N  ...       C8N       C8A      C9NP      C9IP  \
# 0  8.028073  6.381046  9.598324  ...  7.060207  5.897693  5.231254  9.390761
#
#         C9N       C9A    C10NP     C10IP      C10N      C10A
# 0  4.992742  3.516019  1.14882  5.289111  0.680566  0.697045
#
# [1 rows x 23 columns]

# %% [markdown]
# # step 2

# %%
y_pred54 = B(y_pred23)
print(y_pred54.sum(axis=1))
y_pred54.head()
# Out:
# 0    100.0
# dtype: float64
#      O2    METHANE    ETHANE    PROPANE    BUTANE    IPENTANE    PENTANE  \
# 0   0.0        0.0       0.0    0.04099   0.08198     0.68043   1.203686
#
#      T2PENTEN        CP       3MP  ...      TEMH       3MN    TBCYHXAN  \
# 0    0.016396  0.162816  2.241508  ...  1.319701  3.079975    0.680566
#
#      DECANE     ODEBZ    UNDECANE      PNBZ    DODECANE    HXBNZN    TRIDECAN
# 0  0.963369  0.651806    0.182203  0.037895    0.003248  0.007344         0.0
#
# [1 rows x 54 columns]

# %% [markdown]
# # step3

# %%
case_col = ['Case Conditions_Feed Rate to C013 (Input)', 
            'Case Conditions_C7+ in Light End (Input)', 
            'Case Conditions_Heart Cut Prod. Rate (Input)', 
            'Case Conditions_C6P- in Heart Cut (Input)']
case = pd.DataFrame(index=[0],columns=case_col)
case.iloc[0,:] = [10,2.5,100,1]

y_pred58 = pd.concat([case,y_pred54],axis=1)
y_pred58
# Out:
#   Case Conditions_Feed Rate to C013 (Input)  \
# 0                                        10
#
#   Case Conditions_C7+ in Light End (Input)  \
# 0                                      2.5
#
#   Case Conditions_Heart Cut Prod. Rate (Input)  \
# 0                                          100
#
#   Case Conditions_C6P- in Heart Cut (Input)    O2    METHANE    ETHANE  \
# 0                                         1   0.0        0.0       0.0
#
#      PROPANE    BUTANE    IPENTANE  ...      TEMH       3MN    TBCYHXAN  \
# 0    0.04099   0.08198     0.68043  ...  1.319701  3.079975    0.680566
#
#      DECANE     ODEBZ    UNDECANE      PNBZ    DODECANE    HXBNZN    TRIDECAN
# 0  0.963369  0.651806    0.182203  0.037895    0.003248  0.007344         0.0
#
# [1 rows x 58 columns]

# %%
sp162 = C.predict(y_pred58)
print(sp162.sum(axis=1))
sp162
# Out:
# 0    54.0
# dtype: float32
#    Individual Component to Light End Split Factor_Oxygen  \
# 0                                           0.999589
#
#    Individual Component to Heart Cut Split Factor_Oxygen  \
# 0                                           0.000239
#
#    Individual Component to Heavy End Split Factor_Oxygen  \
# 0                                           0.000172
#
#    Individual Component to Light End Split Factor_Methane  \
# 0                                            0.99905
#
#    Individual Component to Heart Cut Split Factor_Methane  \
# 0                                           0.000421
#
#    Individual Component to Heavy End Split Factor_Methane  \
# 0                                           0.000529
#
#    Individual Component to Light End Split Factor_Ethane  \
# 0                                           0.999365
#
#    Individual Component to Heart Cut Split Factor_Ethane  \
# 0                                           0.000312
#
#    Individual Component to Heavy End Split Factor_Ethane  \
# 0                                           0.000323
#
#    Individual Component to Light End Split Factor_Propane  ...  \
# 0                                           0.993451       ...
#
#    Individual Component to Heavy End Split Factor_n-Pentylbenzene  \
# 0                                           0.455619
#
#    Individual Component to Light End Split Factor_n-Dodecane  \
# 0                                            0.00011
#
#    Individual Component to Heart Cut Split Factor_n-Dodecane  \
# 0                                           0.539224
#
#    Individual Component to Heavy End Split Factor_n-Dodecane  \
# 0                                           0.460666
#
#    Individual Component to Light End Split Factor_n-Hexylbenzene  \
# 0                                           0.000115
#
#    Individual Component to Heart Cut Split Factor_n-Hexylbenzene  \
# 0                                           0.533525
#
#    Individual Component to Heavy End Split Factor_n-Hexylbenzene  \
# 0                                            0.46636
#
#    Individual Component to Light End Split Factor_n-Tridecane  \
# 0                                           0.000473
#
#    Individual Component to Heart Cut Split Factor_n-Tridecane  \
# 0                                             0.0004
#
#    Individual Component to Heavy End Split Factor_n-Tridecane
# 0                                           0.999127
#
# [1 rows x 162 columns]

# %% [markdown]
# # step4

# %%
xna = y_pred58.iloc[:,4:]
y_162 = D(xna,sp162)
print(y_162.sum(axis=1))
y_162
# Out:
# 0    300.0
# dtype: float64
#    Light End Product Properties_Oxygen  Light End Product Properties_Methane  \
# 0                                  0.0                                   0.0
#
#    Light End Product Properties_Ethane  Light End Product Properties_Propane  \
# 0                                  0.0                              0.421979
#
#    Light End Product Properties_n-Butane  \
# 0                               0.838138
#
#    Light End Product Properties_i-Pentane  \
# 0                                6.897575
#
#    Light End Product Properties_n-Pentane  \
# 0                               12.137448
#
#    Light End Product Properties_tr2-Pentene  \
# 0                                  0.165839
#
#    Light End Product Properties_Cyclopentane  \
# 0                                   1.609041
#
#    Light End Product Properties_3-Methylpentane  ...  \
# 0                                     21.202916  ...
#
#    Heavy End Product Properties_2,2,3,3-Tetramethylhexane  \
# 0                                           5.564101
#
#    Heavy End Product Properties_3-Methylnonane  \
# 0                                    14.332924
#
#    Heavy End Product Properties_tert-Butylcyclohexane  \
# 0                                           3.202436
#
#    Heavy End Product Properties_n-Decane  \
# 0                               4.667093
#
#    Heavy End Product Properties_1,2-Diethylbenzene  \
# 0                                         3.300911
#
#    Heavy End Product Properties_n-Undecane  \
# 0                                 0.974414
#
#    Heavy End Product Properties_n-Pentylbenzene  \
# 0                                      0.205776
#
#    Heavy End Product Properties_n-Dodecane  \
# 0                                 0.017835
#
#    Heavy End Product Properties_n-Hexylbenzene  \
# 0                                      0.04082
#
#    Heavy End Product Properties_n-Tridecane
# 0                                       0.0
#
# [1 rows x 162 columns]

# %%
print(y_162[D.le].sum(axis=1))
print(y_162[D.hc].sum(axis=1))
print(y_162[D.he].sum(axis=1))
# Out:
# 0    100.0
# dtype: float64
# 0    100.0
# dtype: float64
# 0    100.0
# dtype: float64
